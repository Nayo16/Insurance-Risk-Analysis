# %% [markdown]
# # 03 - Modeling
# Starter notebook for claim probability and severity models.

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv(Path('..') / 'data' / 'insurance_data.csv', sep='\t', parse_dates=['TransactionDate'])
df['HasClaim'] = (df['TotalClaims']>0).astype(int)
X = df[['CustomValueEstimate']].fillna(0)
y = df['TotalClaims']
X.head()
