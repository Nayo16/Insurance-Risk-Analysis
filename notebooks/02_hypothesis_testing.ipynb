# %% [markdown]
# # 02 - Hypothesis Testing
# Guided tests for categorical and numerical drivers of risk.

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv(Path('..') / 'data' / 'insurance_data.csv', sep='\t', parse_dates=['TransactionDate'])
df['HasClaim'] = (df['TotalClaims']>0).astype(int)
df.head()
